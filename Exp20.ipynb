# %% [markdown]
# <a href="https://colab.research.google.com/github/thanusripinky02/DSA0301-NLP/blob/main/Exp20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

documents = [
    "Python is a programming language",
    "Python is used for machine learning",
    "Machine learning is a part of artificial intelligence"
]

query = ["Python machine learning"]

vectorizer = TfidfVectorizer()

doc_vectors = vectorizer.fit_transform(documents)
query_vector = vectorizer.transform(query)

scores = cosine_similarity(query_vector, doc_vectors)[0]

print("Document Ranking:")

for i in scores.argsort()[::-1]:
    print("Document", i + 1, "Score:", round(scores[i], 3))
# Out:
# Document Ranking:
# Document 2 Score: 0.652
# Document 3 Score: 0.374
# Document 1 Score: 0.257
