# %% [markdown]
# <a href="https://colab.research.google.com/github/thanusripinky02/DSA0301-NLP/blob/main/Exp4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def plural(noun):
    if noun.endswith(("s", "x", "z", "ch", "sh")):
        return noun + "es"
    elif noun.endswith("y") and noun[-2] not in "aeiou":
        return noun[:-1] + "ies"
    else:
        return noun + "s"


words = ["cat", "box", "bus", "baby", "book"]

for word in words:
    print(word, "->", plural(word))
# Out:
# cat -> cats
# box -> boxes
# bus -> buses
# baby -> babies
# book -> books
